# %%
import numpy as np
import pandas as pd

# %%
col_array = ['label', 'label_id', 'speed', 'heading_x', 'heading_y', 'heading_z', 'acceleration_x', 'acceleration_y', 'acceleration_z', 'gyroscope_x', 'gyroscope_y', 'gyroscope_z', 'magnetic_field_x', 'magnetic_field_y', 'magnetic_field_z', 'pressure_hPa', 'log_timestamp']

# %%
path = "posmo/experiments/data/posmo_segments/v8/"

# %%
def read_values(csv, col_array, path="posmo/experiments/data/posmo_segments/v8/"):
    return pd.read_csv(path + csv).loc[:, col_array]

# %%
x1 = read_values("Bus-20180423T0929-djordje@datamap.io-F068A314-DC4D-4FB0-9D97-E79929993E41.csv", col_array)

# %%
with pd.option_context('display.max_rows', 501):
    display(x1.loc[:500])
# Out:
#     label  label_id     speed  heading_x  heading_y  heading_z  \
# 0     Bus         6       NaN -15.042789  -5.876207 -10.344269
# 1     Bus         6       NaN        NaN        NaN        NaN
# 2     Bus         6       NaN -15.270493  -5.586946 -10.268921
# 3     Bus         6       NaN -15.365738  -5.686590 -10.424591
# 4     Bus         6       NaN -15.343067  -5.303495 -10.610199
# 5     Bus         6       NaN        NaN        NaN        NaN
# 6     Bus         6       NaN -15.736465  -4.589415 -10.884613
# 7     Bus         6       NaN -16.048782  -4.047903 -10.780792
# 8     Bus         6       NaN -15.883251  -3.765074 -11.200165
# 9     Bus         6       NaN -16.052395  -2.523909 -11.481873
# 10    Bus         6       NaN        NaN        NaN        NaN
# 11    Bus         6       NaN -16.291092  -2.020914 -11.486694
# 12    Bus         6       NaN -16.234669  -1.565962 -11.667450
# 13    Bus         6       NaN -16.329987  -0.777639 -11.994934
# ...
